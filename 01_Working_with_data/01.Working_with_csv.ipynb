# %% [markdown]
# # 1. Import padans

# %%
import pandas as pd

# %% [markdown]
# # 2. Opening csv file

# %%
df = pd.read_csv('aug_train.csv')

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# # 3. Open csv file through the link

# %%
import requests

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
c = pd.read_csv(url)

# %%
c.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# # 3. Seprated parameter

# %%
pd.read_csv('sample-1.tsv', sep='\t').head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         NaN    JANUARY        NaN        NaN        NaN        NaN
# 1         NaN          S          M          T          W          T
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN          2          3          4          5          6
# 4         NaN          9         10         11         12         13
#
#   Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9  ... Unnamed: 17 Unnamed: 18  \
# 0        NaN        NaN         NaN   FEBRUARY  ...       MARCH         NaN
# 1          F          S         NaN          S  ...           S           M
# 2        NaN          1         NaN        NaN  ...         NaN         NaN
# 3          7          8         NaN          6  ...           6           7
# 4         14         15         NaN         13  ...          13          14
#
#   Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  Unnamed: 23 Unnamed: 24  \
# ...

# %%
pd.read_csv('aug_train.csv', index_col="enrollee_id").head()
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
#
#             enrolled_university education_level major_discipline experience  \
# enrollee_id
# 8949              no_enrollment        Graduate             STEM        >20
# 29725             no_enrollment        Graduate             STEM         15
# 11561          Full time course        Graduate             STEM          5
# 33241                       NaN        Graduate  Business Degree         <1
# 666               no_enrollment         Masters             STEM        >20
#
# ...

# %% [markdown]
# # Header parameter

# %%
pd.read_csv('aug_train.csv',header=0) #It is used when we want to any make a column names
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # use col parameter

# %%
# you specifies a column which you want

# %%
pd.read_csv('aug_train.csv',usecols=['enrollee_id', 'city'])
# Out:
#        enrollee_id      city
# 0             8949  city_103
# 1            29725   city_40
# 2            11561   city_21
# 3            33241  city_115
# 4              666  city_162
# ...            ...       ...
# 19153         7386  city_173
# 19154        31398  city_103
# 19155        24576  city_103
# 19156         5756   city_65
# 19157        23834   city_67
#
# [19158 rows x 2 columns]

# %% [markdown]
# # skiprows/nrows

# %%
pd.read_csv('aug_train.csv',skiprows=[0,1,4])              #you can also pass labda function
# Out:
#        29725   city_40  0.7759999999999999  Male   No relevent experience  \
# 0      11561   city_21               0.624   NaN   No relevent experience
# 1        666  city_162               0.767  Male  Has relevent experience
# 2      21651  city_176               0.764   NaN  Has relevent experience
# 3      28806  city_160               0.920  Male  Has relevent experience
# 4        402   city_46               0.762  Male  Has relevent experience
# ...      ...       ...                 ...   ...                      ...
# 19150   7386  city_173               0.878  Male   No relevent experience
# 19151  31398  city_103               0.920  Male  Has relevent experience
# 19152  24576  city_103               0.920  Male  Has relevent experience
# 19153   5756   city_65               0.802  Male  Has relevent experience
# 19154  23834   city_67               0.855   NaN   No relevent experience
#
#           no_enrollment        Graduate        STEM   15    50-99  \
# ...

# %%
pd.read_csv('aug_train.csv',nrows=100).head()    #How much require  torw
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# # Encoding parameters

# %%
pd.read_csv('aug_train.csv',encoding='latin-1')  # if data support different encoding so we open file in this ecoding by specifis encoding parameters or you cna change the data by any text editor
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Skip bad line

# %%
# It is used when some data exist more columns as camparison to another data

# %%
pd.read_csv('aug_train.csv',on_bad_lines='skip')
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # dtype

# %%
pd.read_csv('aug_train.csv',dtype={'target':int}).head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# # Handling data

# %%
#This is used to when some data exist date type by default it treat as a object but convert it into data date type

# %%
pd.read_csv('aug_train.csv',parse_dates=['target']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  object
# ...

# %% [markdown]
# # Convertor

# %%
# Some time you want to convert data into short name like mumbai indians = MI, so we use convertor pass the function
# pd.read_csv('aug_train.csv', converters={'columns-name':function})

# %% [markdown]
# # na_parameter

# %%
# some data set contains null values = - , nan , NAN, null etc
# so we pass some value which consider a null value
pd.read_csv('aug_train.csv', na_values=['Male'])
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920    NaN
# 1            29725   city_40                   0.776    NaN
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767    NaN
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878    NaN
# 19154        31398  city_103                   0.920    NaN
# 19155        24576  city_103                   0.920    NaN
# 19156         5756   city_65                   0.802    NaN
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # Loading the huge amount of data into chunks

# %%
df = pd.read_csv('aug_train.csv', chunksize=5000)
for chunks
