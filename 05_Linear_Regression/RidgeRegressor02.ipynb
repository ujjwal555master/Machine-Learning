# %% [markdown]
# # In this we will create a self class of ridge regressor

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

# %%
plt.scatter(X, y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import Ridge

# %%
rr1 = Ridge(alpha=0)
rr1.fit(X_train, y_train)
# Out:
# Ridge(alpha=0)

# %%
rr2 = Ridge(alpha=10)
rr2.fit(X_train, y_train)
# Out:
# Ridge(alpha=10)

# %%
rr3 = Ridge(alpha=1000)
rr3.fit(X_train, y_train)
# Out:
# Ridge(alpha=1000)

# %%
plt.plot(X,y, 'b.')
plt.plot(X_test, rr1.predict(X_test), color='red', label='alplh=0')
plt.plot(X_test, rr2.predict(X_test), color='b', label='alplh=0')
plt.plot(X_test, rr3.predict(X_test), color='y', label='alplh=0')
#plt.legend()

# %%
class RidgeReg:
    def __init__(self, alpha=1):
        self.m = None
        self.b = None
        self.alpha = alpha

    def fit(self, x_train, y_train):
        num = 0
        din = 0
        for i in range(x_train.shape[0]):
            num = num + (y_train[i] - y_train.mean()) * (x_train[i] - x_train.mean())
            din = din + (x_train[i] - x_train.mean()) * (x_train[i] - x_train.mean())

        self.m = num/(din + self.alpha)
        self.b = y_train.mean() - (self.m*x_train.mean())
        print(self.m,self.b)

    def predict(self):
        pass

# %%
rd = RidgeReg(alpha=100)

# %%
rd.fit(X, y)
# Out:
# [12.93442104] [-1.42484415]

# %% [markdown]
# # Ridge regressor class for the Multideminsional data

# %%
class MeraRidge:
    
    def __init__(self,alpha=0.1):
        
        self.alpha = alpha
        self.coef_ = None
        self.intercept_ = None
        
    def fit(self,X_train,y_train):
        
        X_train = np.insert(X_train,0,1,axis=1)
        I = np.identity(X_train.shape[1])
        I[0][0] = 0
        result = np.linalg.inv(np.dot(X_train.T,X_train) + self.alpha * I).dot(X_train.T).dot(y_train)
        self.intercept_ = result[0]
        self.coef_ = result[1:]
    
    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
i[0][0] = 0

# %%
i
# Out:
# array([[0., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
