# %% [markdown]
# ## 1. How are coefficients affected?

# %%
from sklearn.datasets import load_diabetes

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score

from sklearn.model_selection import train_test_split

# %%
data = load_diabetes()

df = pd.DataFrame(data.data,columns=data.feature_names)
df['TARGET'] = data.target

df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  TARGET
# 0 -0.002592  0.019908 -0.017646   151.0
# 1 -0.039493 -0.068330 -0.092204    75.0
# 2 -0.002592  0.002864 -0.025930   141.0
# 3  0.034309  0.022692 -0.009362   206.0
# 4 -0.002592 -0.031991 -0.046641   135.0

# %%
X_train,X_test,y_train,y_test = train_test_split(data.data,data.target,test_size=0.2,random_state=2)

# %%
coefs = []
r2_scores = []

for i in [0,0.1,1,10]:
    reg = Lasso(alpha=i)
    reg.fit(X_train,y_train)
    
    coefs.append(reg.coef_.tolist())
    y_pred = reg.predict(X_test)
    r2_scores.append(r2_score(y_test,y_pred))
# Out:
# <ipython-input-93-73bb2b6a9955>:6: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   reg.fit(X_train,y_train)
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 496708.2205472759, tolerance: 212.4353654390935
#   model = cd_fast.enet_coordinate_descent(

# %%
plt.figure(figsize=(14,9))
plt.subplot(221)
plt.bar(data.feature_names,coefs[0])
plt.title('Alpha = 0 ,r2_score = {}'.format(round(r2_scores[0],2)))

plt.subplot(222)
plt.bar(data.feature_names,coefs[1])
plt.title('Alpha = 0.1 ,r2_score = {}'.format(round(r2_scores[1],2)))

plt.subplot(223)
plt.bar(data.feature_names,coefs[2])
plt.title('Alpha = 1 ,r2_score = {}'.format(round(r2_scores[2],2)))

plt.subplot(224)
plt.bar(data.feature_names,coefs[3])
plt.title('Alpha = 10 ,r2_score = {}'.format(round(r2_scores[3],2)))

plt.show()

# %% [markdown]
# ## 2. Higher Coefficients are affected more

# %%
alphas = [0,0.0001,0.001,0.01,0.1,1,10,100,1000,10000]

coefs = []

for i in alphas:
    reg = Lasso(alpha=i)
    reg.fit(X_train,y_train)
    
    coefs.append(reg.coef_.tolist())
# Out:
# <ipython-input-95-3ebec9db6c83>:7: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   reg.fit(X_train,y_train)
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 496708.2205472759, tolerance: 212.4353654390935
#   model = cd_fast.enet_coordinate_descent(

# %%
input_array = np.array(coefs)

coef_df = pd.DataFrame(input_array,columns=data.feature_names)
coef_df['alpha'] = alphas
coef_df.set_index('alpha')
# Out:
#                  age         sex         bmi          bp          s1  \
# alpha
# 0.0000     -9.160885 -205.462260  516.684624  340.627341 -895.543596
# 0.0001     -9.071288 -205.337332  516.780313  340.539730 -888.652320
# 0.0010     -8.264924 -204.213177  517.641106  339.751339 -826.653342
# 0.0100     -1.361404 -192.944226  526.348511  332.649058 -430.205495
# 0.1000      0.000000 -113.976046  526.737112  292.635423  -82.691928
# 1.0000      0.000000    0.000000  363.882636   27.278420    0.000000
# 10.0000     0.000000    0.000000    0.000000    0.000000    0.000000
# 100.0000    0.000000    0.000000    0.000000    0.000000    0.000000
# 1000.0000   0.000000    0.000000    0.000000    0.000000    0.000000
# 10000.0000  0.000000    0.000000    0.000000    0.000000    0.000000
#
#                     s2          s3          s4          s5         s6
# alpha
# 0.0000      561.214523  153.884780  126.734314  861.121395  52.419828
# 0.0001      555.952271  150.585260  125.453044  858.639860  52.379002
# 0.0010      508.609613  120.899583  113.924518  836.314382  52.011583
# 0.0100      191.277876  -44.048113   68.990747  688.384976  47.939528
# 0.1000       -0.000000 -152.691332    0.000000  551.077200   7.169852
# 1.0000        0.000000   -0.000000    0.000000  336.135971   0.000000
# 10.0000       0.000000   -0.000000    0.000000    0.000000   0.000000
# 100.0000      0.000000   -0.000000    0.000000    0.000000   0.000000
# 1000.0000     0.000000   -0.000000    0.000000    0.000000   0.000000
# 10000.0000    0.000000   -0.000000    0.000000    0.000000   0.000000

# %%
alphas = [0,0.0001,0.0005,0.001,0.005,0.1,0.5,1,5,10]

coefs = []

for i in alphas:
    reg = Lasso(alpha=i)
    reg.fit(X_train,y_train)
    
    coefs.append(reg.coef_.tolist())
# Out:
# <ipython-input-97-a6313f20dc56>:7: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   reg.fit(X_train,y_train)
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 496708.2205472759, tolerance: 212.4353654390935
#   model = cd_fast.enet_coordinate_descent(

# %%
input_array = np.array(coefs).T

plt.figure(figsize=(15,8))
plt.plot(alphas,np.zeros(len(alphas)),color='black',linewidth=5)
for i in range(input_array.shape[0]):
    plt.plot(alphas,input_array[i],label=data.feature_names[i])
plt.legend()

# %% [markdown]
# ## 3. Impact on Bias and Variance

# %%
m = 100
X = 5 * np.random.rand(m, 1) - 2
y = 0.7 * X ** 2 - 2 * X + 3 + np.random.randn(m, 1)

plt.scatter(X, y)
plt.show()

# %%
X_train,X_test,y_train,y_test = train_test_split(X.reshape(100,1),y.reshape(100),test_size=0.2,random_state=2)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=10)

X_train = poly.fit_transform(X_train)
X_test = poly.transform(X_test)

# %%
from mlxtend.evaluate import bias_variance_decomp

alphas = np.linspace(0,30,100)

loss = []
bias = []
variance = []

for i in alphas:
    reg = Lasso(alpha=i)
    avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
        reg, X_train, y_train, X_test, y_test, 
        loss='mse',
        random_seed=123)
    loss.append(avg_expected_loss)
    bias.append(avg_bias)
    variance.append(avg_var)
# Out:
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.86300793450192, tolerance: 0.0485070993099066
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36.56454151424337, tolerance: 0.03948048731775189
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.28877543665209, tolerance: 0.057010418148890324
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.899608686326445, tolerance: 0.03730290146622043
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53.77309403483095, tolerance: 0.06882453806342814
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 59.147150942052555, tolerance: 0.052725042446096215
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.57649464383037, tolerance: 0.03686072327162291
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56.21031092448653, tolerance: 0.0557174148488382
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.02330301572306, tolerance: 0.04058676587288989
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.34506036667756, tolerance: 0.045517078075883406
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.209829375996776, tolerance: 0.043629209562748496
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.06289771526946, tolerance: 0.040768320311091746
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.42284052655326, tolerance: 0.049593730038536975
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.55924951603009, tolerance: 0.04550976724205836
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36.77380761680877, tolerance: 0.04819912712333085
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:109: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   pred = estimator.fit(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8839528285953975, tolerance: 0.04901026745994457
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.725215499277397, tolerance: 0.05124629395754687
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.6245077445975937, tolerance: 0.0472844944994882
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19231158910633894, tolerance: 0.03623888357548313
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12359572175188305, tolerance: 0.061985794837021504
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.014306249682107, tolerance: 0.02771199748822096
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.655185378162457, tolerance: 0.04622014952770892
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.95316882505665, tolerance: 0.04783777320393546
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.564125238511423, tolerance: 0.04794133095297326
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0753408541028193, tolerance: 0.04572837786222473
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.59436109325904, tolerance: 0.04780917812753589
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.46008668810486597, tolerance: 0.05862505022214026
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6248342878447204, tolerance: 0.04168613139475897
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.48425393595838, tolerance: 0.04167171437986697
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6198847405156585, tolerance: 0.054305291449966105
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16.782961761561694, tolerance: 0.03481528643813497
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06863279696938207, tolerance: 0.04005133281059201
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.061254383639948, tolerance: 0.04736069538824559
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.3883424367205066, tolerance: 0.053309205072978046
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.4799455552597465, tolerance: 0.04610503433432359
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.721219708614285, tolerance: 0.049475615220856174
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.092073311837282, tolerance: 0.04840073247238547
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26396855273782194, tolerance: 0.045230180338376946
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.877371477729014, tolerance: 0.03848999037272757
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62.86547504864396, tolerance: 0.05492324372915632
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22105450447256203, tolerance: 0.03835173068810442
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.887912791057886, tolerance: 0.05505105959996943
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2658676265639599, tolerance: 0.04331778433384541
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 80.73855426024008, tolerance: 0.04961844773732665
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08529731777340999, tolerance: 0.03184552465948883
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.623486540465876, tolerance: 0.053167515431612335
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0983430115769579, tolerance: 0.0498392510314815
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.951795448016071, tolerance: 0.04920125082678727
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.959321185625583, tolerance: 0.04442598676603375
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.124250408194655, tolerance: 0.04726679318763386
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3368200754995314, tolerance: 0.03722289022404689
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6412049373191735, tolerance: 0.05673523962929802
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.5098977411709313, tolerance: 0.03601986797285881
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.861484521833745, tolerance: 0.0551253175592655
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\91842\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.059830710048459, tolerance: 0.05517903575499296
#   model = cd_fast.enet_coordinate_descent(

# %%
plt.plot(alphas,loss,label='loss')
plt.plot(alphas,bias,label='Bias')
plt.plot(alphas,variance,label='Variance')
plt.xlabel('Alpha')
plt.legend()

# %% [markdown]
# ## 4. Effect of Regularization on Loss Function

# %%
from sklearn.datasets import make_regression

X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

plt.scatter(X,y)

from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X,y)
print(reg.coef_)
print(reg.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %%
def cal_loss(m,alpha):
    return np.sum((y - m*X.ravel() + 2.29)**2) + alpha*abs(m)

# %%
def predict(m):
    return m*X - 2.29

# %%
m = np.linspace(-45,100,100)
plt.figure(figsize=(12,12))
for j in [0,100,500,1000,2500,3500,4500,5500]:
    loss = []
    for i in range(m.shape[0]):
        loss_i = cal_loss(m[i],j)
        loss.append(loss_i)
    plt.plot(m,loss,label='alpha = {}'.format(j))
plt.legend()
plt.xlabel('Alpha')
plt.ylabel('Loss')
plt.show()
